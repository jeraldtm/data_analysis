# %%
from analysis import AMRAnalysis

# %%
data = AMRAnalysis()

# %%
files = 'refurb_probe_42861_STFMRC3_AMRAng_P00.0_B0.08000_2019-05-13_1.csv'

# %%
data.load_sweep('./', procedure_files = [file])

# %%
data.calculate_AMR_resistance()
data.plot_AMR_angle_dependence()
