# %%
from analysis import STFMRAnalysis, plot_dataset, fit_dataset, combine_new_dim
import xarray as xr
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
from glob import glob
import hvplot.xarray

# %%
CE6_fswp = STFMRAnalysis()
CE6_fswp.load_sweep('../2019-07-04', 'CE6_STFMRC3_STFMR_series_2019-07-04_1.txt')
CE6_fswp.separate_field_data(90, reverse=True)

# %%
fit = CE6_fswp.fit_resonances(1, 0.01, 1e-7, 1e-7, maxfev = 10000)

# %%
fit.plot_fits()

# %%
Meff_fit = CE6_fswp_fit.find_Meff()
Meff_fit.fit_ds
# Out:
# <xarray.Dataset>
# Dimensions:        (field_azimuth: 2)
# Coordinates:
#   * field_azimuth  (field_azimuth) float64 45.0 225.0
# Data variables:
#     Meff           (field_azimuth) float64 0.9031 0.9151
#     Meff_err       (field_azimuth) float64 9.162e-05 0.0001197

# %%
Meff_fit.plot_fits(fmt='.')

# %%
fit.plot_resonance_components()

# %%
fit.calculate_SHE(0.903, 5e-9, 8e-9)
# Out:
# <xarray.DataArray 'SHE' (rf_freq: 7, field_azimuth: 2)>
# array([[0.082243, 0.091868],
#        [0.086975, 0.084607],
#        [0.092684, 0.086931],
#        [0.086882, 0.091837],
#        [0.091855, 0.086685],
#        [0.098658, 0.08613 ],
#        [0.096977, 0.084863]])
# Coordinates:
#   * rf_freq        (rf_freq) float64 4.0 5.0 6.0 7.0 8.0 9.0 10.0
#   * field_azimuth  (field_azimuth) float64 45.0 225.0
